# %% [markdown]
# # **Cuaderno de ETL: De Datos Abiertos a un Modelo de Estrella**
#
# **Objetivo:** Tomar un conjunto de datos públicos sobre estadísticas de educación en Colombia y transformarlo en un modelo dimensional de estrella, listo para ser analizado con herramientas de Business Intelligence.
#
# **Fuente de Datos:** [MEN_ESTADISTICAS_EN_EDUCACION_EN_PREESCOLAR-B-SICA](https://www.datos.gov.co/Educaci-n/MEN_ESTADISTICAS_EN_EDUCACION_EN_PREESCOLAR-B-SICA/nudc-7mev/about_data)
#
# **Nuestro Modelo de Estrella a Construir:**
#
# * **Tabla de Hechos (Fact_Matriculas):**
#     * `id_tiempo` (FK)
#     * `id_geografia` (FK)
#     * `total_matriculados` (Métrica)
#     ...
#
# * **Tablas de Dimensiones:**
#     * `Dim_Tiempo` (año)
#     * `Dim_Geografia` (departamento, municipio)
#
# ¡Manos a la obra!

# %%
# ===================================================================
# PASO 1: CONFIGURACIÓN E INSTALACIÓN DE LIBRERÍAS
# ===================================================================

import pandas as pd
import requests
import sqlite3

print("✅ Librerías importadas.")
# Out:
# ✅ Librerías importadas.

# %%
# ===================================================================
# PASO 2: EXTRACCIÓN (EXTRACT) DE LOS DATOS
# ===================================================================

# La plataforma datos.gov.co usa la API de Socrata. Podemos usarla para
# descargar los datos directamente, lo que es más eficiente que bajar un CSV.
# Aumentamos el límite para traer más filas (ajusta si es necesario).
api_url = "https://www.datos.gov.co/resource/nudc-7mev.json?$limit=50000"

print(f"📥 Extrayendo datos desde: {api_url}")

try:
    response = requests.get(api_url)
    response.raise_for_status()  # Lanza un error si la petición falla (ej: 404)
    data = response.json()
    df_raw = pd.DataFrame(data)
    print(f"✅ ¡Extracción exitosa! Se cargaron {len(df_raw)} filas.")
    display(df_raw.head())

except requests.exceptions.RequestException as e:
    print(f"❌ Error al extraer los datos: {e}")
    df_raw = pd.DataFrame() # Creamos un dataframe vacío para evitar errores posteriores

except Exception as e:
    print(f"❌ Ocurrió un error inesperado: {e}")
    df_raw = pd.DataFrame()
# Out:
# 📥 Extrayendo datos desde: https://www.datos.gov.co/resource/nudc-7mev.json?$limit=50000
# ✅ ¡Extracción exitosa! Se cargaron 14585 filas.
#     a_o c_digo_municipio   municipio c_digo_departamento departamento  \
# 0  2023            05004    Abriaquí                  05    Antioquia
# 1  2023            95025  El Retorno                  95     Guaviare
# 2  2023            95200  Miraflores                  95     Guaviare
# 3  2023            97001        Mitú                  97       Vaupés
# 4  2023            97161      Caruru                  97       Vaupés
#
#   c_digo_etc              etc poblaci_n_5_16 tasa_matriculaci_n_5_16  \
# 0       3758  Antioquia (ETC)            503                   62.62
# 1       3830   Guaviare (ETC)           4438                   53.27
# 2       3830   Guaviare (ETC)           2014                   32.52
# 3       3831     Vaupés (ETC)          10986                   59.57
# 4       3831     Vaupés (ETC)           1228                    51.3
#
#   cobertura_neta  ... reprobaci_n_primaria reprobaci_n_secundaria  \
# 0          62.62  ...                 1.96                  16.51
# 1          53.27  ...                 7.11                   9.39
# 2          32.52  ...                 6.93                  14.13
# 3          59.57  ...                 4.04                   8.33
# 4           51.3  ...                 7.32                  15.28
#
#   reprobaci_n_media repitencia repitencia_transici_n repitencia_primaria  \
# 0              2.04       9.52                     0               10.46
# 1              1.75       9.34                  6.95               11.84
# 2              7.81       8.65                  6.67                9.04
# 3               4.6      16.18                  7.75               21.04
# 4              7.27       9.24                  2.86                7.62
#
#   repitencia_secundaria repitencia_media tama_o_promedio_de_grupo  \
# 0                 13.76             2.04                      NaN
# 1                  8.48             3.16                      NaN
# 2                 10.25             1.54                      NaN
# 3                 13.84             7.18                      NaN
# 4                 14.85             3.64                      NaN
#
#   sedes_conectadas_a_internet
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
#
# [5 rows x 41 columns]

# %%
df_raw
# Out:
#         a_o c_digo_municipio    municipio c_digo_departamento departamento  \
# 0      2023            05004     Abriaquí                  05    Antioquia
# 1      2023            95025   El Retorno                  95     Guaviare
# 2      2023            95200   Miraflores                  95     Guaviare
# 3      2023            97001         Mitú                  97       Vaupés
# 4      2023            97161       Caruru                  97       Vaupés
# ...     ...              ...          ...                 ...          ...
# 14580  2011             5036  Angelópolis                   5    Antioquia
# 14581  2011             5034        Andes                   5    Antioquia
# 14582  2011             5031       Amalfi                   5    Antioquia
# 14583  2011             5030        Amagá                   5    Antioquia
# 14584  2011             5021   Alejandría                   5    Antioquia
#
#       c_digo_etc              etc poblaci_n_5_16 tasa_matriculaci_n_5_16  \
# 0           3758  Antioquia (ETC)            503                   62.62
# 1           3830   Guaviare (ETC)           4438                   53.27
# 2           3830   Guaviare (ETC)           2014                   32.52
# 3           3831     Vaupés (ETC)          10986                   59.57
# 4           3831     Vaupés (ETC)           1228                    51.3
# ...          ...              ...            ...                     ...
# 14580       3758  Antioquia (ETC)           1707                   78.85
# 14581       3758  Antioquia (ETC)          10244                   84.45
# 14582       3758  Antioquia (ETC)           5552                   97.71
# 14583       3758  Antioquia (ETC)           6631                   78.65
# 14584       3758  Antioquia (ETC)            702                  118.52
#
#       cobertura_neta  ... reprobaci_n_primaria reprobaci_n_secundaria  \
# 0              62.62  ...                 1.96                  16.51
# 1              53.27  ...                 7.11                   9.39
# 2              32.52  ...                 6.93                  14.13
# 3              59.57  ...                 4.04                   8.33
# 4               51.3  ...                 7.32                  15.28
# ...              ...  ...                  ...                    ...
# 14580           78.9  ...                 3.61                    9.5
# 14581           84.5  ...                 0.58                   0.04
# 14582           97.7  ...                    0                      0
# 14583           78.7  ...                 6.73                  14.46
# 14584          118.5  ...                 2.16                   4.39
#
#       reprobaci_n_media repitencia repitencia_transici_n repitencia_primaria  \
# 0                  2.04       9.52                     0               10.46
# 1                  1.75       9.34                  6.95               11.84
# 2                  7.81       8.65                  6.67                9.04
# 3                   4.6      16.18                  7.75               21.04
# 4                  7.27       9.24                  2.86                7.62
# ...                 ...        ...                   ...                 ...
# 14580              7.32       0.71                     0                 0.7
# 14581              2.69       5.41                  0.73                5.53
# 14582                 0        NaN                  0.83                 NaN
# 14583              7.45       0.42                     0                0.24
# 14584              8.04        0.6                     0                0.96
#
#       repitencia_secundaria repitencia_media tama_o_promedio_de_grupo  \
# 0                     13.76             2.04                      NaN
# 1                      8.48             3.16                      NaN
# 2                     10.25             1.54                      NaN
# 3                     13.84             7.18                      NaN
# 4                     14.85             3.64                      NaN
# ...                     ...              ...                      ...
# 14580                  1.08                0                    19.57
# 14581                   6.9             4.11                    24.43
# 14582                  9.93             4.47                    20.01
# 14583                  0.91                0                    25.05
# 14584                     0                0                    32.14
#
#       sedes_conectadas_a_internet
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ...                           ...
# 14580                         100
# 14581                       93.44
# 14582                       53.45
# 14583                       83.33
# 14584                       81.25
#
# [14585 rows x 41 columns]

# %%
conn = sqlite3.connect('../Datos/Educacion.bd')

# %%
df_raw.to_sql('Educacion',conn)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df_raw.to_sql('Educacion',conn)
#
# File c:\Users\mikuy\.conda\envs\diplomado_env\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\mikuy\.conda\envs\diplomado_env\Lib\site-packages\pandas\core\generic.py:3106, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2908 """
#    2909 Write records stored in a DataFrame to a SQL database.
#    2910
#    (...)
#    3102 [(1,), (None,), (2,)]
#    3103 """  # noqa: E501
#    3104 from pandas.io import sql
# -> 3106 return sql.to_sql(
#    3107     self,
#    3108     name,
#    3109     con,
#    3110     schema=schema,
#    3111     if_exists=if_exists,
#    3112     index=index,
#    3113     index_label=index_label,
#    3114     chunksize=chunksize,
#    3115     dtype=dtype,
#    3116     method=method,
#    3117 )
#
# File c:\Users\mikuy\.conda\envs\diplomado_env\Lib\site-packages\pandas\io\sql.py:844, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     839     raise NotImplementedError(
#     840         "'frame' argument should be either a Series or a DataFrame"
#     841     )
#     843 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 844     return pandas_sql.to_sql(
#     845         frame,
#     846         name,
#     847         if_exists=if_exists,
#     848         index=index,
#     849         index_label=index_label,
#     850         schema=schema,
#     851         chunksize=chunksize,
#     852         dtype=dtype,
#     853         method=method,
#     854         engine=engine,
#     855         **engine_kwargs,
#     856     )
#
# File c:\Users\mikuy\.conda\envs\diplomado_env\Lib\site-packages\pandas\io\sql.py:2840, in SQLiteDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    2829             raise ValueError(f"{col} ({my_type}) not a string")
#    2831 table = SQLiteTable(
#    2832     name,
#    2833     self,
#    (...)
#    2838     dtype=dtype,
#    2839 )
# -> 2840 table.create()
#    2841 return table.insert(chunksize, method)
#
# File c:\Users\mikuy\.conda\envs\diplomado_env\Lib\site-packages\pandas\io\sql.py:988, in SQLTable.create(self)
#     986 if self.exists():
#     987     if self.if_exists == "fail":
# --> 988         raise ValueError(f"Table '{self.name}' already exists.")
#     989     if self.if_exists == "replace":
#     990         self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'Educacion' already exists.

# %%
cursor = conn.cursor()

# %%
pd.read_sql('SELECT * FROM Educacion', con=conn)
# Out:
#        index   a_o c_digo_municipio    municipio c_digo_departamento  \
# 0          0  2023            05004     Abriaquí                  05
# 1          1  2023            95025   El Retorno                  95
# 2          2  2023            95200   Miraflores                  95
# 3          3  2023            97001         Mitú                  97
# 4          4  2023            97161       Caruru                  97
# ...      ...   ...              ...          ...                 ...
# 14580  14580  2011             5036  Angelópolis                   5
# 14581  14581  2011             5034        Andes                   5
# 14582  14582  2011             5031       Amalfi                   5
# 14583  14583  2011             5030        Amagá                   5
# 14584  14584  2011             5021   Alejandría                   5
#
#       departamento c_digo_etc              etc poblaci_n_5_16  \
# 0        Antioquia       3758  Antioquia (ETC)            503
# 1         Guaviare       3830   Guaviare (ETC)           4438
# 2         Guaviare       3830   Guaviare (ETC)           2014
# 3           Vaupés       3831     Vaupés (ETC)          10986
# 4           Vaupés       3831     Vaupés (ETC)           1228
# ...            ...        ...              ...            ...
# 14580    Antioquia       3758  Antioquia (ETC)           1707
# 14581    Antioquia       3758  Antioquia (ETC)          10244
# 14582    Antioquia       3758  Antioquia (ETC)           5552
# 14583    Antioquia       3758  Antioquia (ETC)           6631
# 14584    Antioquia       3758  Antioquia (ETC)            702
#
#       tasa_matriculaci_n_5_16  ... reprobaci_n_primaria  \
# 0                       62.62  ...                 1.96
# 1                       53.27  ...                 7.11
# 2                       32.52  ...                 6.93
# 3                       59.57  ...                 4.04
# 4                        51.3  ...                 7.32
# ...                       ...  ...                  ...
# 14580                   78.85  ...                 3.61
# 14581                   84.45  ...                 0.58
# 14582                   97.71  ...                    0
# 14583                   78.65  ...                 6.73
# 14584                  118.52  ...                 2.16
#
#       reprobaci_n_secundaria reprobaci_n_media repitencia  \
# 0                      16.51              2.04       9.52
# 1                       9.39              1.75       9.34
# 2                      14.13              7.81       8.65
# 3                       8.33               4.6      16.18
# 4                      15.28              7.27       9.24
# ...                      ...               ...        ...
# 14580                    9.5              7.32       0.71
# 14581                   0.04              2.69       5.41
# 14582                      0                 0       None
# 14583                  14.46              7.45       0.42
# 14584                   4.39              8.04        0.6
#
#       repitencia_transici_n repitencia_primaria repitencia_secundaria  \
# 0                         0               10.46                 13.76
# 1                      6.95               11.84                  8.48
# 2                      6.67                9.04                 10.25
# 3                      7.75               21.04                 13.84
# 4                      2.86                7.62                 14.85
# ...                     ...                 ...                   ...
# 14580                     0                 0.7                  1.08
# 14581                  0.73                5.53                   6.9
# 14582                  0.83                None                  9.93
# 14583                     0                0.24                  0.91
# 14584                     0                0.96                     0
#
#       repitencia_media tama_o_promedio_de_grupo sedes_conectadas_a_internet
# 0                 2.04                     None                        None
# 1                 3.16                     None                        None
# 2                 1.54                     None                        None
# 3                 7.18                     None                        None
# 4                 3.64                     None                        None
# ...                ...                      ...                         ...
# 14580                0                    19.57                         100
# 14581             4.11                    24.43                       93.44
# 14582             4.47                    20.01                       53.45
# 14583                0                    25.05                       83.33
# 14584                0                    32.14                       81.25
#
# [14585 rows x 42 columns]

# %%
def ejecutar_sql(query, conexion=conn):
  """
  Toma una consulta SQL, la ejecuta y devuelve el resultado
  en una tabla de pandas para una visualización clara.
  """
  df = pd.read_sql_query(query, conexion)
  # Usamos display() porque en Colab presenta las tablas de forma más elegante.
  display(df)

# %%
ejecutar_sql("SELECT departamento, COUNT (municipio) as total FROM Educacion GROUP BY departamento")
# Out:
#                                          departamento  total
# 0                                            Amazonas    143
# 1                                           Antioquia   1625
# 2                                              Arauca     91
# 3   Archipiélago de San Andrés, Providencia y Sant...     24
# 4   Archipiélago de San Andrés. Providencia y Sant...      2
# 5                                           Atlántico    299
# 6                                         Bogotá D.C.      1
# 7                                        Bogotá, D.C.     12
# 8                                             Bolívar    598
# 9                                              Boyacá   1599
# 10                                             Caldas    351
# 11                                            Caquetá    208
# 12                                           Casanare    247
# 13                                              Cauca    546
# 14                                              Cesar    325
# 15                                              Chocó    390
# 16                                       Cundinamarca   1508
# 17                                            Córdoba    390
# 18                                            Guainía    113
# 19                                           Guaviare     52
# 20                                              Huila    481
# 21                                         La Guajira    195
# 22                                          Magdalena    390
# 23                                               Meta    377
# 24                                           NACIONAL      3
# 25                                             Nariño    832
# 26                                 Norte de Santander    520
# 27                                           Putumayo    169
# 28                                            Quindio    156
# 29                                          Risaralda    182
# 30                                          Santander   1131
# 31                                              Sucre    338
# 32                                             Tolima    611
# 33                                    Valle del Cauca    546
# 34                                             Vaupés     78
# 35                                            Vichada     52

# %% [markdown]
# ## **3. Transformación (Transform)**
#
# Esta es la fase más importante. Aquí limpiamos los datos crudos y los moldeamos para que encajen en nuestro modelo de estrella.
#
# **Pasos:**
# 1.  **Limpieza y Preparación:** Convertiremos las columnas a los tipos de datos correctos y manejaremos valores faltantes. La columna `matricula` es nuestra métrica principal.
# 2.  **Creación de Dimensiones:** A partir del DataFrame limpio, crearemos una tabla (DataFrame) para cada dimensión, asegurándonos de que no tengan filas duplicadas y asignando una **llave subrogada** (un ID numérico único).
# 3.  **Creación de la Tabla de Hechos:** Construiremos la tabla de hechos, que contendrá nuestra métrica (`total_matriculados`) y las llaves foráneas que la conectan a cada dimensión.

# %%
ejecutar_sql("""
PRAGMA table_info(Educacion);
""")
# Out:
#     cid                         name     type  notnull dflt_value  pk
# 0     0                        index  INTEGER        0       None   0
# 1     1                          a_o     TEXT        0       None   0
# 2     2             c_digo_municipio     TEXT        0       None   0
# 3     3                    municipio     TEXT        0       None   0
# 4     4          c_digo_departamento     TEXT        0       None   0
# 5     5                 departamento     TEXT        0       None   0
# 6     6                   c_digo_etc     TEXT        0       None   0
# 7     7                          etc     TEXT        0       None   0
# 8     8               poblaci_n_5_16     TEXT        0       None   0
# 9     9      tasa_matriculaci_n_5_16     TEXT        0       None   0
# 10   10               cobertura_neta     TEXT        0       None   0
# 11   11    cobertura_neta_transici_n     TEXT        0       None   0
# 12   12      cobertura_neta_primaria     TEXT        0       None   0
# 13   13    cobertura_neta_secundaria     TEXT        0       None   0
# 14   14         cobertura_neta_media     TEXT        0       None   0
# 15   15              cobertura_bruta     TEXT        0       None   0
# 16   16   cobertura_bruta_transici_n     TEXT        0       None   0
# 17   17     cobertura_bruta_primaria     TEXT        0       None   0
# 18   18   cobertura_bruta_secundaria     TEXT        0       None   0
# 19   19        cobertura_bruta_media     TEXT        0       None   0
# 20   20                    deserci_n     TEXT        0       None   0
# 21   21         deserci_n_transici_n     TEXT        0       None   0
# 22   22           deserci_n_primaria     TEXT        0       None   0
# 23   23         deserci_n_secundaria     TEXT        0       None   0
# 24   24              deserci_n_media     TEXT        0       None   0
# 25   25                   aprobaci_n     TEXT        0       None   0
# 26   26        aprobaci_n_transici_n     TEXT        0       None   0
# 27   27          aprobaci_n_primaria     TEXT        0       None   0
# 28   28        aprobaci_n_secundaria     TEXT        0       None   0
# 29   29             aprobaci_n_media     TEXT        0       None   0
# 30   30                  reprobaci_n     TEXT        0       None   0
# 31   31       reprobaci_n_transici_n     TEXT        0       None   0
# 32   32         reprobaci_n_primaria     TEXT        0       None   0
# 33   33       reprobaci_n_secundaria     TEXT        0       None   0
# 34   34            reprobaci_n_media     TEXT        0       None   0
# 35   35                   repitencia     TEXT        0       None   0
# 36   36        repitencia_transici_n     TEXT        0       None   0
# 37   37          repitencia_primaria     TEXT        0       None   0
# 38   38        repitencia_secundaria     TEXT        0       None   0
# 39   39             repitencia_media     TEXT        0       None   0
# 40   40     tama_o_promedio_de_grupo     TEXT        0       None   0
# 41   41  sedes_conectadas_a_internet     TEXT        0       None   0

# %%
def ejecutar_sql(query, conexion=conn):
    """
    Ejecuta una consulta SQL. Si es un SELECT, muestra el resultado como tabla.
    Si no, ejecuta sin retorno (DROP, CREATE, etc.).
    """
    if query.strip().lower().startswith("select"):
        df = pd.read_sql_query(query, conexion)
        display(df)
    else:
        cursor = conexion.cursor()
        cursor.execute(query)
        conexion.commit()
        print("✅ Consulta ejecutada correctamente.")

# %%
ejecutar_sql("DROP TABLE IF EXISTS Educacion_Limpia")
# Out:
# ✅ Consulta ejecutada correctamente.

# %%
ejecutar_sql("""
CREATE TABLE Educacion_Limpia AS
SELECT
    CAST(a_o AS INTEGER) AS anio,
    departamento,
    municipio,
    CAST(poblaci_n_5_16 AS REAL) AS poblacion,
    CAST(tasa_matriculaci_n_5_16 AS REAL) AS tasa_matriculacion,
    CAST(cobertura_neta AS REAL) AS cobertura_neta,
    CAST(aprobaci_n AS REAL) AS aprobacion,
    CAST(reprobaci_n AS REAL) AS reprobacion
FROM Educacion
WHERE a_o IS NOT NULL
  AND departamento IS NOT NULL
  AND municipio IS NOT NULL
  AND poblaci_n_5_16 IS NOT NULL
  AND tasa_matriculaci_n_5_16 IS NOT NULL
  AND cobertura_neta IS NOT NULL;
""")
# Out:
# ✅ Consulta ejecutada correctamente.

# %%
pd.read_sql('SELECT * FROM Educacion_Limpia', con=conn)
# Out:
#        anio departamento    municipio  poblacion  tasa_matriculacion  \
# 0      2023    Antioquia     Abriaquí      503.0               62.62
# 1      2023     Guaviare   El Retorno     4438.0               53.27
# 2      2023     Guaviare   Miraflores     2014.0               32.52
# 3      2023       Vaupés         Mitú    10986.0               59.57
# 4      2023       Vaupés       Caruru     1228.0               51.30
# ...     ...          ...          ...        ...                 ...
# 14446  2011    Antioquia  Angelópolis     1707.0               78.85
# 14447  2011    Antioquia        Andes    10244.0               84.45
# 14448  2011    Antioquia       Amalfi     5552.0               97.71
# 14449  2011    Antioquia        Amagá     6631.0               78.65
# 14450  2011    Antioquia   Alejandría      702.0              118.52
#
#        cobertura_neta  aprobacion  reprobacion
# 0               62.62       92.26         6.55
# 1               53.27       87.67         6.78
# 2               32.52       82.68         9.47
# 3               59.57       90.71         5.34
# 4               51.30       82.40         9.24
# ...               ...         ...          ...
# 14446           78.90       86.27         5.59
# 14447           84.50       95.46         0.58
# 14448           97.70       91.25         0.00
# 14449           78.70       86.86         8.99
# 14450          118.50       92.39         3.58
#
# [14451 rows x 8 columns]

# %%
ejecutar_sql("DROP TABLE IF EXISTS Dim_Tiempo;")
# Out:
# ✅ Consulta ejecutada correctamente.

# %%
ejecutar_sql("""
CREATE TABLE Dim_Tiempo AS
SELECT 
    anio,
    ROW_NUMBER() OVER (ORDER BY anio) AS id_tiempo
FROM (
    SELECT DISTINCT anio
    FROM Educacion_Limpia
    WHERE anio IS NOT NULL
)
""")
# Out:
# ✅ Consulta ejecutada correctamente.

# %%
pd.read_sql('SELECT * FROM Dim_Tiempo;', con=conn)
# Out:
#     anio  id_tiempo
# 0   2011          1
# 1   2012          2
# 2   2013          3
# 3   2014          4
# 4   2015          5
# 5   2016          6
# 6   2017          7
# 7   2018          8
# 8   2019          9
# 9   2020         10
# 10  2021         11
# 11  2022         12
# 12  2023         13

# %%
ejecutar_sql("DROP TABLE IF EXISTS Dim_Geografia;")
# Out:
# ✅ Consulta ejecutada correctamente.

# %%
ejecutar_sql("""
CREATE TABLE Dim_Geografia AS
SELECT 
    departamento,
    municipio,
    ROW_NUMBER() OVER (ORDER BY departamento, municipio) AS id_geografia
FROM (
    SELECT DISTINCT departamento, municipio
    FROM Educacion_Limpia
    WHERE departamento IS NOT NULL AND municipio IS NOT NULL
);
""")
# Out:
# ✅ Consulta ejecutada correctamente.

# %%
pd.read_sql('SELECT * FROM Dim_Geografia;', con=conn)
# Out:
#      departamento       municipio  id_geografia
# 0        Amazonas      El Encanto             1
# 1        Amazonas     La Chorrera             2
# 2        Amazonas      La Pedrera             3
# 3        Amazonas     La Victoria             4
# 4        Amazonas         Leticia             5
# ...           ...             ...           ...
# 1121       Vaupés        Yavaraté          1122
# 1122      Vichada        Cumaribo          1123
# 1123      Vichada    La Primavera          1124
# 1124      Vichada  Puerto Carreño          1125
# 1125      Vichada   Santa Rosalía          1126
#
# [1126 rows x 3 columns]

# %%
ejecutar_sql("DROP TABLE IF EXISTS Fact_Educacion;")
# Out:
# ✅ Consulta ejecutada correctamente.

# %%
ejecutar_sql("""
CREATE TABLE Fact_Educacion AS
SELECT 
    t.id_tiempo,
    g.id_geografia,
    AVG(e.poblacion) AS poblacion,
    AVG(e.tasa_matriculacion) AS tasa_matriculacion,
    AVG(e.cobertura_neta) AS cobertura_neta,
    AVG(e.aprobacion) AS aprobacion,
    AVG(e.reprobacion) AS reprobacion
FROM Educacion_Limpia e
JOIN Dim_Tiempo t ON e.anio = t.anio
JOIN Dim_Geografia g ON e.departamento = g.departamento AND e.municipio = g.municipio
GROUP BY t.id_tiempo, g.id_geografia;
""")
# Out:
# ✅ Consulta ejecutada correctamente.

# %%
pd.read_sql('SELECT * FROM Fact_Educacion;', con=conn)
# Out:
#        id_tiempo  id_geografia  poblacion  tasa_matriculacion  cobertura_neta  \
# 0              1             1     1543.0               31.43           31.40
# 1              1             2     1135.0               54.45           54.50
# 2              1             3     1433.0               72.99           73.00
# 3              1             5    11410.0              108.20          108.20
# 4              1             8      488.0               40.78           40.80
# ...          ...           ...        ...                 ...             ...
# 14446         13          1122      561.0               47.95           47.95
# 14447         13          1123    25357.0               49.85           49.85
# 14448         13          1124     2659.0               95.94           95.94
# 14449         13          1125     4641.0              144.52          144.52
# 14450         13          1126     1159.0               83.87           83.87
#
#        aprobacion  reprobacion
# 0           95.43         2.29
# 1           96.53         0.42
# 2           95.96         0.09
# 3           90.02         4.04
# 4           94.55         0.00
# ...           ...          ...
# 14446       95.55         0.00
# 14447       76.05        16.45
# 14448       83.33        10.23
# 14449       80.93        13.26
# 14450       85.26         9.82
#
# [14451 rows x 7 columns]

# %% [markdown]
# ### Porcentaje de escolaridad (tasa de matrícula 5–16 años) por municipio

# %%
ejecutar_sql("""
SELECT 
    g.departamento,
    g.municipio,
    ROUND(f.tasa_matriculacion, 2) AS tasa_matriculacion,
    ROUND(f.cobertura_neta, 2) AS cobertura_neta
FROM Fact_Educacion f
JOIN Dim_Geografia g ON f.id_geografia = g.id_geografia
ORDER BY f.tasa_matriculacion DESC
LIMIT 10;
""")
# Out:
#    departamento         municipio  tasa_matriculacion  cobertura_neta
# 0     Atlántico   Puerto Colombia              279.03          139.67
# 1     Atlántico   Puerto Colombia              273.80          264.54
# 2     Atlántico   Puerto Colombia              266.50          257.24
# 3  Cundinamarca              Cota              240.70          238.62
# 4  Cundinamarca              Cota              239.34          199.98
# 5  Cundinamarca              Cota              236.70          233.99
# 6  Cundinamarca              Cota              197.50          196.15
# 7  Cundinamarca              Cota              195.16          193.44
# 8     Santander  Sabana de Torres              194.87           94.17
# 9  Cundinamarca              Cota              193.34          191.50

# %% [markdown]
# ### Comparación de rendimiento educativo por municipio (aprobación vs. reprobación)

# %%
ejecutar_sql("""
SELECT 
    g.departamento,
    g.municipio,
    ROUND(f.tasa_matriculacion, 2) AS tasa_matriculacion,
    ROUND(f.cobertura_neta, 2) AS cobertura_neta
FROM Fact_Educacion f
JOIN Dim_Geografia g ON f.id_geografia = g.id_geografia
ORDER BY f.tasa_matriculacion DESC
LIMIT 10;
""")
# Out:
#    departamento         municipio  tasa_matriculacion  cobertura_neta
# 0     Atlántico   Puerto Colombia              279.03          139.67
# 1     Atlántico   Puerto Colombia              273.80          264.54
# 2     Atlántico   Puerto Colombia              266.50          257.24
# 3  Cundinamarca              Cota              240.70          238.62
# 4  Cundinamarca              Cota              239.34          199.98
# 5  Cundinamarca              Cota              236.70          233.99
# 6  Cundinamarca              Cota              197.50          196.15
# 7  Cundinamarca              Cota              195.16          193.44
# 8     Santander  Sabana de Torres              194.87           94.17
# 9  Cundinamarca              Cota              193.34          191.50

# %% [markdown]
# ###  Departamentos con mejor cobertura neta

# %%
ejecutar_sql("""
SELECT 
    g.departamento,
    ROUND(AVG(f.cobertura_neta), 2) AS cobertura_promedio
FROM Fact_Educacion f
JOIN Dim_Geografia g ON f.id_geografia = g.id_geografia
GROUP BY g.departamento
ORDER BY cobertura_promedio DESC
LIMIT 10;
""")
# Out:
#    departamento  cobertura_promedio
# 0   Bogotá D.C.               95.89
# 1       Quindio               94.58
# 2         Sucre               93.85
# 3         Cesar               93.81
# 4     Magdalena               93.28
# 5          Meta               90.74
# 6        Tolima               89.24
# 7  Bogotá, D.C.               88.96
# 8      Casanare               88.58
# 9  Cundinamarca               88.55

# %% [markdown]
# ## Preguntas
#
# 1. Respecto a la población del municipio ¿Que porcentaje de escolaridad hay?
#
# 2. ¿Cómo compararía el rendimiento educativo por municipios?
#
# 3. ¿Que departamentos son los que mejor cobertura tienen? ¿Pueden hacer cálculo con SQL?

# %% [markdown]
# Este ejercicio se entrega en un archivo Jupyter Notebook (.ipynb) que contenga el código necesario para realizar las consultas en SQL y que previamente haya creado la bodega de datos con un modelo dimensional adecuado.

# %% [markdown]
# 1. Respecto a la población del municipio ¿Que porcentaje de escolaridad hay?

# %%
ejecutar_sql("""
SELECT 
    g.departamento,
    g.municipio,
    ROUND(f.tasa_matriculacion, 2) AS porcentaje_escolaridad
FROM Fact_Educacion f
JOIN Dim_Geografia g ON f.id_geografia = g.id_geografia
JOIN Dim_Tiempo t ON f.id_tiempo = t.id_tiempo
WHERE t.anio = (
    SELECT MAX(anio) FROM Dim_Tiempo
)
ORDER BY porcentaje_escolaridad DESC
LIMIT 10;
""")
# Out:
#    departamento        municipio  porcentaje_escolaridad
# 0  Cundinamarca             Cota                  186.72
# 1  Cundinamarca        La Calera                  160.56
# 2  Cundinamarca          Fúquene                  155.74
# 3     Atlántico  Puerto Colombia                  155.14
# 4       Quindio          Salento                  151.46
# 5       Vichada   Puerto Carreño                  144.52
# 6  Cundinamarca            Tenjo                  143.05
# 7        Nariño        Cumbitara                  127.64
# 8     Antioquia      La Estrella                  125.77
# 9  Cundinamarca       Subachoque                  125.75

# %% [markdown]
# 2. ¿Cómo compararía el rendimiento educativo por municipios?
#    Municipios con alta aprobación y baja reprobación muestran un mejor desempeño educativo.

# %%
ejecutar_sql("""
SELECT 
    g.departamento,
    g.municipio,
    ROUND(f.aprobacion, 2) AS aprobacion,
    ROUND(f.reprobacion, 2) AS reprobacion,
    t.anio
FROM Fact_Educacion f
JOIN Dim_Geografia g ON f.id_geografia = g.id_geografia
JOIN Dim_Tiempo t ON f.id_tiempo = t.id_tiempo
WHERE t.anio = (SELECT MAX(anio) FROM Dim_Tiempo)
ORDER BY aprobacion DESC
LIMIT 10;
""")
# Out:
#    departamento     municipio  aprobacion  reprobacion  anio
# 0      Amazonas   La Victoria      100.00         0.00  2023
# 1        Vaupés       Taraira      100.00         0.00  2023
# 2        Nariño        Nariño       99.78         0.00  2023
# 3      Amazonas  Puerto Arica       99.62         0.38  2023
# 4  Cundinamarca      Tibirita       99.50         0.00  2023
# 5        Nariño   Providencia       99.42         0.15  2023
# 6        Nariño      Pupiales       99.29         0.04  2023
# 7  Cundinamarca      La Palma       98.81         0.00  2023
# 8  Cundinamarca          Gama       98.74         0.00  2023
# 9        Nariño       La Tola       98.30         0.00  2023

# %%
ejecutar_sql("""
SELECT 
    g.departamento,
    g.municipio,
    ROUND(f.aprobacion, 2) AS aprobacion,
    ROUND(f.reprobacion, 2) AS reprobacion,
    t.anio
FROM Fact_Educacion f
JOIN Dim_Geografia g ON f.id_geografia = g.id_geografia
JOIN Dim_Tiempo t ON f.id_tiempo = t.id_tiempo
WHERE t.anio = (SELECT MAX(anio) FROM Dim_Tiempo)
ORDER BY aprobacion ASC
LIMIT 10;
""")
# Out:
#       departamento        municipio  aprobacion  reprobacion  anio
# 0           Vaupés         Papunaua        0.00         0.00  2023
# 1          Guainía  Puerto Colombia       70.24        22.24  2023
# 2          Guainía       San Felipe       72.89        11.11  2023
# 3          Vichada         Cumaribo       76.05        16.45  2023
# 4            Huila     La Argentina       77.46        16.36  2023
# 5  Valle del Cauca     Ansermanuevo       77.64        11.70  2023
# 6          Guainía         Cacahual       77.68        14.68  2023
# 7         Amazonas    Puerto Nariño       78.27        12.06  2023
# 8          Guainía     La Guadalupe       78.95        15.79  2023
# 9        Antioquia         Hispania       79.14         7.65  2023

# %% [markdown]
# 3. ¿Que departamentos son los que mejor cobertura tienen? ¿Pueden hacer cálculo con SQL?

# %%
ejecutar_sql("""
SELECT 
    g.departamento,
    ROUND(AVG(f.cobertura_neta), 2) AS cobertura_promedio,
    t.anio
FROM Fact_Educacion f
JOIN Dim_Geografia g ON f.id_geografia = g.id_geografia
JOIN Dim_Tiempo t ON f.id_tiempo = t.id_tiempo
WHERE t.anio = (SELECT MAX(anio) FROM Dim_Tiempo)
GROUP BY g.departamento, t.anio
ORDER BY cobertura_promedio DESC
LIMIT 10;
""")
# Out:
#                                         departamento  cobertura_promedio  anio
# 0                                            Quindio               95.08  2023
# 1                                            Vichada               93.55  2023
# 2                                       Bogotá, D.C.               92.40  2023
# 3                                             Tolima               90.29  2023
# 4                                              Sucre               89.71  2023
# 5                                            Bolívar               89.64  2023
# 6                                               Meta               89.29  2023
# 7                                          Magdalena               88.81  2023
# 8  Archipiélago de San Andrés, Providencia y Sant...               88.22  2023
# 9                                       Cundinamarca               87.98  2023

# %% [markdown]
# MODELO ESTRELLA RESULTANTE
# Tabla de Hechos: Fact_Educacion
#
# id_tiempo, id_geografia, poblacion, tasa_matriculacion, cobertura_neta, aprobacion, reprobacion
#
# Dim_Tiempo: id_tiempo, anio
#
# Dim_Geografia: id_geografia, departamento, municipio

# %%
# Cerramos la conexión
conn.close()
print("Conexión a la base de datos cerrada.")
# Out:
# Conexión a la base de datos cerrada.
